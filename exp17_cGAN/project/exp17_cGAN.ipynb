# %% [markdown]
# # exp17. 프로젝트 : Segmentation map으로 도로 이미지 만들기

# %% [markdown]
# ## 0. 들어가며

# %% [markdown]
# 이전 Pix2Pix 논문에서 제시한 결과 중에 아래와 같은 실험 결과가 있었습니다. 도로의 레이블 정보를 활용해 이미지를 생성해낸 결과입니다.
#
# ![](https://d3s0tskafalll9.cloudfront.net/media/images/p2p_result_seg.max-800x600.png)
#
# 이번 프로젝트는 위와 같은 데이터셋을 이용해 Pix2Pix를 학습시켜보는 것입니다. 데이터셋은 아래에서 다운로드할 수 있습니다.
# 1000개의 학습용 이미지 및 5개의 평가 이미지를 포함합니다.
#
# cityscapes.zip
#
# 이전 포켓몬 데이터에서 사용했던 스케치와는 조금 다른 레이블 정보 이미지를 입력으로 사용하기 때문에, 전처리 과정에 대해 약간의 혼란이 있을 수 있지만 크게 다른 과정은 없습니다.
# 아래 Tensroflow에서 제공하는 Pix2Pix 튜토리얼은 위 이미지와 비슷한 레이블 정보 이미지를 사용하기 때문에 좋은 참고 자료가 될 수 있을 것 같습니다.
#
# 프로젝트 시작에 어려움이 있다면 아래 튜토리얼을 참고하시면서 이번 프로젝트를 수행해 봅시다.
# (아래 튜토리얼은 Pix2Pix 구조를 Functional API를 이용해 구현하기 때문에 이번에 진행한 Subclassing 방법을 이용한 모델 구현과 비교하면서 구현 방법에 대해서도 공부해 보시길 추천드립니다)
#
# * Tensorflow Pix2Pix Tutorial(https://www.tensorflow.org/tutorials/generative/pix2pix?hl=ko)
#
# 프로젝트를 수행하기 전에 주요 라이브러리 버전을 살펴 봅시다.

# %% [markdown]
# ### 0.1 라이브러리 확인

# %%
import numpy as np
import tensorflow as tf
import cv2
import matplotlib.pyplot as plt

from tensorflow.keras import layers, Input, Model

print(np.__version__)
print(tf.__version__)
# Out:
# 1.19.2
# 2.4.0

# %% [markdown]
# ### 0.2 프로젝트 수행
# ***
# 프로젝트를 진행하면서 필수로 수행해야 할 사항은 다음과 같습니다.
#
# 1. 데이터에 한 가지 이상의 augmentation 방법을 적용하여 학습해 주세요.
# (어떠한 방법을 사용했는지 적어주세요.)
# 2. 이전에 구현했던 두 개의 Generator 중 Encoder와 Decoder간에 skip connection이 있는 U-Net Generator를 사용해 주세요.
# 3. 모델 학습 후, 학습된 Generator를 이용해 테스트합니다. 테스트 데이터는 다운로드했던 "val" 폴더 내 이미지를 사용해 주세요.
# 4. 1개 이상의 이미지에 대해 테스트 과정을 거친 후 그 결과를 스케치, 생성된 사진, 실제 사진 순서로 나란히 시각화해 주세요.
# 5. 모델을 충분히 학습하기에 시간이 부족할 수 있습니다. 적어도 10 epoch 이상 학습하며 중간 손실 값에 대한 로그를 남겨주세요. 좋은 결과를 얻기 위해선 긴 학습 시간이 필요하므로 테스트 결과는 만족스럽지 않아도 괜찮습니다.

# %% [markdown]
# ### 0.3 루브릭
# ***
# |**평가문항**|**상세기준**|
# |------------|-------------|
# |1.   pix2pix 모델 학습을 위해 필요한 데이터셋을 적절히 구축하였다.|데이터 분석 과정 및 한 가지 이상의 augmentation을 포함한 데이터셋 구축 과정이 체계적으로 제시되었다.|
# |2.  pix2pix 모델을 구현하여 성공적으로 학습 과정을 진행하였다.|U-Net generator, discriminator 모델 구현이 완료되어 train_step이 안정적으로 진행됨을 확인하였다.|
# |3. 학습 과정 및 테스트에 대한 시각화 결과를 제출하였다.|10 epoch 이상의 학습을 진행한 후 최종 테스트 결과에서 진행한 epoch 수에 걸맞은 정도의 품질을 확인하였다.|

# %% [markdown]
# ## 1. 데이터 준비 및 확인

# %% [markdown]
# ### 1.1 데이터 불러오기

# %%
data_path = 'D:/project/aiffel_exp/data/exp17/cityscapes/train/'
print("number of train examples :", len(os.listdir(data_path)))
# Out:
# number of train examples : 1000

# %%
val_path = 'D:/project/aiffel_exp/data/exp17/cityscapes/val/'
print("number of val examples :", len(os.listdir(val_path)))
# Out:
# number of val examples : 5

# %% [markdown]
# * train data = 1,000
# * val data = 5

# %% [markdown]
# ### 1.2 데이터 시각화 및 분할

# %%
# train data 시각화

plt.figure(figsize=(20,15))
for i in range(1, 7):
    f = data_path + os.listdir(data_path)[np.random.randint(3)]
    img = cv2.imread(f, cv2.IMREAD_COLOR)
    plt.subplot(3,2,i)
    plt.imshow(img)

# %%
# 데이터 크기 확인

f = data_path + os.listdir(data_path)[0]
img = cv2.imread(f, cv2.IMREAD_COLOR)
print(img.shape)
# Out:
# (256, 512, 3)

# %%
# 이미지 분할

def normalize(x):
    x = tf.cast(x, tf.float32)
    return (x/127.5) - 1

def denormalize(x):
    x = (x+1)*127.5
    x = x.numpy()
    return x.astype(np.uint8)

def load_img(img_path):
    img = tf.io.read_file(img_path)
    img = tf.image.decode_image(img, 3)
    
    w = tf.shape(img)[1] // 2
    sketch = img[:, :w, :] 
    sketch = tf.cast(sketch, tf.float32)
    colored = img[:, w:, :] 
    colored = tf.cast(colored, tf.float32)
    return normalize(sketch), normalize(colored)

f = data_path + os.listdir(data_path)[1]
sketch, colored = load_img(f)

plt.figure(figsize=(10,7))
plt.subplot(1,2,1); plt.imshow(denormalize(sketch))
plt.subplot(1,2,2); plt.imshow(denormalize(colored))

# %% [markdown]
# ### 1.3 augmentation

# %% [markdown]
# `apply_augmentation` 함수는 스케치 및 채색된 2개 이미지를 입력으로 받아 여러 가지 연산을 두 이미지에 동일하게 적용합니다.
#
# 1. 두 이미지가 채널 축으로 연결됩니다. (tf.concat). 두 이미지가 각각 3채널인 경우 6채널이 됩니다.
# 2. 1.의 결과에 각 50% 확률로 Refection padding 또는 constant padding이 30픽셀의 pad width 만큼적용됩니다. (tf.pad)
# 3. 2.의 결과에서 (256,256,6) 크기를 가진 이미지를 임의로 잘라냅니다. (tf.image.random_crop)
# 4. 3.의 결과를 50% 확률로 가로로 뒤집습니다. (tf.image.random_flip_left_right)
# 5. 4.의 결과를 50% 확률로 세로로 뒤집습니다. (tf.image.random_flip_up_down)
# 6. 5.의 결과를 50% 확률로 회전시킵니다. (tf.image.rot90)

# %%
# apply_augmentation 함수

from tensorflow import image
from tensorflow.keras.preprocessing.image import random_rotation

@tf.function() # 빠른 텐서플로 연산을 위해 @tf.function()을 사용합니다. 
def apply_augmentation(sketch, colored):
    stacked = tf.concat([sketch, colored], axis=-1)
    
    _pad = tf.constant([[30,30],[30,30],[0,0]])
    if tf.random.uniform(()) < .5:
        padded = tf.pad(stacked, _pad, "REFLECT")
    else:
        padded = tf.pad(stacked, _pad, "CONSTANT", constant_values=1.)

    out = image.random_crop(padded, size=[256, 256, 6])
    
    out = image.random_flip_left_right(out)
    out = image.random_flip_up_down(out)
    
    if tf.random.uniform(()) < .5:
        degree = tf.random.uniform([], minval=1, maxval=4, dtype=tf.int32)
        out = image.rot90(out, k=degree)
    
    return out[...,:3], out[...,3:]   

print("✅")
# Out:
# ✅

# %%
plt.figure(figsize=(15,13))
img_n = 1
for i in range(1, 13, 2):
    augmented_sketch, augmented_colored = apply_augmentation(sketch, colored)
    
    plt.subplot(3,4,i)
    plt.imshow(denormalize(augmented_sketch)); plt.title(f"Image {img_n}")
    plt.subplot(3,4,i+1); 
    plt.imshow(denormalize(augmented_colored)); plt.title(f"Image {img_n}")
    img_n += 1

# %%
# train data 전체에 agumentation 적용 후 결과 확인

from tensorflow import data

def get_train(img_path):
    sketch, colored = load_img(img_path)
    sketch, colored = apply_augmentation(sketch, colored)
    return sketch, colored

train_images = data.Dataset.list_files(data_path + "*.jpg")
train_images = train_images.map(get_train).shuffle(100).batch(4)

sample = train_images.take(1)
sample = list(sample.as_numpy_iterator())
sketch, colored = (sample[0][0]+1)*127.5, (sample[0][1]+1)*127.5

plt.figure(figsize=(10,5))
plt.subplot(1,2,1); plt.imshow(sketch[0].astype(np.uint8))
plt.subplot(1,2,2); plt.imshow(colored[0].astype(np.uint8))

# %% [markdown]
# ## 2. Generator 구성

# %% [markdown]
# ### 2.1 encoder 구현하기

# %%
class EncodeBlock(layers.Layer):
    def __init__(self, n_filters, use_bn=True):
        super(EncodeBlock, self).__init__()
        self.use_bn = use_bn       
        self.conv = layers.Conv2D(n_filters, 4, 2, "same", use_bias=False)
        self.batchnorm = layers.BatchNormalization()
        self.lrelu= layers.LeakyReLU(0.2)

    def call(self, x):
        x = self.conv(x)
        if self.use_bn:
            x = self.batchnorm(x)
        return self.lrelu(x)

print("✅")
# Out:
# ✅

# %%
class Encoder(layers.Layer):
    def __init__(self):
        super(Encoder, self).__init__()
        filters = [64,128,256,512,512,512,512,512]
        
        self.blocks = []
        for i, f in enumerate(filters):
            if i == 0:
                self.blocks.append(EncodeBlock(f, use_bn=False))
            else:
                self.blocks.append(EncodeBlock(f))
    
    def call(self, x):
        for block in self.blocks:
            x = block(x)
        return x
    
    def get_summary(self, input_shape=(256,256,3)):
        inputs = Input(input_shape)
        return Model(inputs, self.call(inputs)).summary()

print("✅")
# Out:
# ✅

# %%
# Encoder model 확인

Encoder().get_summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 256, 256, 3)]     0
# _________________________________________________________________
# encode_block (EncodeBlock)   (None, 128, 128, 64)      3072
# _________________________________________________________________
# encode_block_1 (EncodeBlock) (None, 64, 64, 128)       131584
# _________________________________________________________________
# encode_block_2 (EncodeBlock) (None, 32, 32, 256)       525312
# _________________________________________________________________
# encode_block_3 (EncodeBlock) (None, 16, 16, 512)       2099200
# _________________________________________________________________
# encode_block_4 (EncodeBlock) (None, 8, 8, 512)         4196352
# _________________________________________________________________
# encode_block_5 (EncodeBlock) (None, 4, 4, 512)         4196352
# _________________________________________________________________
# encode_block_6 (EncodeBlock) (None, 2, 2, 512)         4196352
# _________________________________________________________________
# encode_block_7 (EncodeBlock) (None, 1, 1, 512)         4196352
# =================================================================
# Total params: 19,544,576
# Trainable params: 19,538,688
# Non-trainable params: 5,888
# _________________________________________________________________

# %% [markdown]
# ### 2.2 decoder 구현하기

# %%
class DecodeBlock(layers.Layer):
    def __init__(self, f, dropout=True):
        super(DecodeBlock, self).__init__()
        self.dropout = dropout
        self.Transconv = layers.Conv2DTranspose(f, 4, 2, "same", use_bias=False)
        self.batchnorm = layers.BatchNormalization()
        self.relu = layers.ReLU()
        
    def call(self, x):
        x = self.Transconv(x)
        x = self.batchnorm(x)
        if self.dropout:
            x = layers.Dropout(.5)(x)
        return self.relu(x)

    
class Decoder(layers.Layer):
    def __init__(self):
        super(Decoder, self).__init__()
        filters = [512,512,512,512,256,128,64]
        
        self.blocks = []
        for i, f in enumerate(filters):
            if i < 3:
                self.blocks.append(DecodeBlock(f))
            else:
                self.blocks.append(DecodeBlock(f, dropout=False))
                
        self.blocks.append(layers.Conv2DTranspose(3, 4, 2, "same", use_bias=False))
        
    def call(self, x):
        for block in self.blocks:
            x = block(x)
        return x
            
    def get_summary(self, input_shape=(1,1,512)):
        inputs = Input(input_shape)
        return Model(inputs, self.call(inputs)).summary()
        
print("✅")
# Out:
# ✅

# %%
# Decoder model 확인

Decoder().get_summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 1, 1, 512)]       0
# _________________________________________________________________
# decode_block (DecodeBlock)   (None, 2, 2, 512)         4196352
# _________________________________________________________________
# decode_block_1 (DecodeBlock) (None, 4, 4, 512)         4196352
# _________________________________________________________________
# decode_block_2 (DecodeBlock) (None, 8, 8, 512)         4196352
# _________________________________________________________________
# decode_block_3 (DecodeBlock) (None, 16, 16, 512)       4196352
# _________________________________________________________________
# decode_block_4 (DecodeBlock) (None, 32, 32, 256)       2098176
# _________________________________________________________________
# decode_block_5 (DecodeBlock) (None, 64, 64, 128)       524800
# _________________________________________________________________
# decode_block_6 (DecodeBlock) (None, 128, 128, 64)      131328
# _________________________________________________________________
# conv2d_transpose_7 (Conv2DTr (None, 256, 256, 3)       3072
# =================================================================
# Total params: 19,542,784
# Trainable params: 19,537,792
# Non-trainable params: 4,992
# _________________________________________________________________

# %% [markdown]
# ### 2.3 Encoder와 Decoder 연결

# %%
class EncoderDecoderGenerator(Model):
    def __init__(self):
        super(EncoderDecoderGenerator, self).__init__()
        self.encoder = Encoder()
        self.decoder = Decoder()
    
    def call(self, x):
        x = self.encoder(x)
        x = self.decoder(x)
        return x
   
    def get_summary(self, input_shape=(256,256,3)):
        inputs = Input(input_shape)
        return Model(inputs, self.call(inputs)).summary()
        

EncoderDecoderGenerator().get_summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         [(None, 256, 256, 3)]     0
# _________________________________________________________________
# encoder_1 (Encoder)          (None, 1, 1, 512)         19544576
# _________________________________________________________________
# decoder_1 (Decoder)          (None, 256, 256, 3)       19542784
# =================================================================
# Total params: 39,087,360
# Trainable params: 39,076,480
# Non-trainable params: 10,880
# _________________________________________________________________

# %% [markdown]
# ### 2.4 U-Net 구조 Generator

# %%
class UNetGenerator(Model):
    def __init__(self):
        super(UNetGenerator, self).__init__()
        encode_filters = [64,128,256,512,512,512,512,512]
        decode_filters = [512,512,512,512,256,128,64]
        
        self.encode_blocks = []
        for i, f in enumerate(encode_filters):
            if i == 0:
                self.encode_blocks.append(EncodeBlock(f, use_bn=False))
            else:
                self.encode_blocks.append(EncodeBlock(f))
        
        self.decode_blocks = []
        for i, f in enumerate(decode_filters):
            if i < 3:
                self.decode_blocks.append(DecodeBlock(f))
            else:
                self.decode_blocks.append(DecodeBlock(f, dropout=False))
        
        self.last_conv = layers.Conv2DTranspose(3, 4, 2, "same", use_bias=False)
    
    def call(self, x):
        features = []
        for block in self.encode_blocks:
            x = block(x)
            features.append(x)
        
        features = features[:-1]
                    
        for block, feat in zip(self.decode_blocks, features[::-1]):
            x = block(x)
            x = layers.Concatenate()([x, feat])
        
        x = self.last_conv(x)
        return x
                
    def get_summary(self, input_shape=(256,256,3)):
        inputs = Input(input_shape)
        return Model(inputs, self.call(inputs)).summary()

print("✅")
# Out:
# ✅

# %%
UNetGenerator().get_summary()
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_4 (InputLayer)            [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# encode_block_16 (EncodeBlock)   (None, 128, 128, 64) 3072        input_4[0][0]
# __________________________________________________________________________________________________
# encode_block_17 (EncodeBlock)   (None, 64, 64, 128)  131584      encode_block_16[0][0]
# __________________________________________________________________________________________________
# encode_block_18 (EncodeBlock)   (None, 32, 32, 256)  525312      encode_block_17[0][0]
# __________________________________________________________________________________________________
# encode_block_19 (EncodeBlock)   (None, 16, 16, 512)  2099200     encode_block_18[0][0]
# __________________________________________________________________________________________________
# encode_block_20 (EncodeBlock)   (None, 8, 8, 512)    4196352     encode_block_19[0][0]
# __________________________________________________________________________________________________
# encode_block_21 (EncodeBlock)   (None, 4, 4, 512)    4196352     encode_block_20[0][0]
# __________________________________________________________________________________________________
# encode_block_22 (EncodeBlock)   (None, 2, 2, 512)    4196352     encode_block_21[0][0]
# __________________________________________________________________________________________________
# encode_block_23 (EncodeBlock)   (None, 1, 1, 512)    4196352     encode_block_22[0][0]
# __________________________________________________________________________________________________
# decode_block_14 (DecodeBlock)   (None, 2, 2, 512)    4196352     encode_block_23[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 2, 2, 1024)   0           decode_block_14[0][0]
#                                                                  encode_block_22[0][0]
# __________________________________________________________________________________________________
# decode_block_15 (DecodeBlock)   (None, 4, 4, 512)    8390656     concatenate[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 4, 4, 1024)   0           decode_block_15[0][0]
#                                                                  encode_block_21[0][0]
# __________________________________________________________________________________________________
# decode_block_16 (DecodeBlock)   (None, 8, 8, 512)    8390656     concatenate_1[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 8, 8, 1024)   0           decode_block_16[0][0]
#                                                                  encode_block_20[0][0]
# __________________________________________________________________________________________________
# decode_block_17 (DecodeBlock)   (None, 16, 16, 512)  8390656     concatenate_2[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 16, 16, 1024) 0           decode_block_17[0][0]
#                                                                  encode_block_19[0][0]
# __________________________________________________________________________________________________
# decode_block_18 (DecodeBlock)   (None, 32, 32, 256)  4195328     concatenate_3[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 32, 32, 512)  0           decode_block_18[0][0]
#                                                                  encode_block_18[0][0]
# __________________________________________________________________________________________________
# decode_block_19 (DecodeBlock)   (None, 64, 64, 128)  1049088     concatenate_4[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 64, 64, 256)  0           decode_block_19[0][0]
#                                                                  encode_block_17[0][0]
# __________________________________________________________________________________________________
# decode_block_20 (DecodeBlock)   (None, 128, 128, 64) 262400      concatenate_5[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 128, 128, 128 0           decode_block_20[0][0]
#                                                                  encode_block_16[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_23 (Conv2DTran (None, 256, 256, 3)  6144        concatenate_6[0][0]
# ==================================================================================================
# Total params: 54,425,856
# Trainable params: 54,414,976
# Non-trainable params: 10,880
# __________________________________________________________________________________________________

# %% [markdown]
# ## 3. Discriminator 구성하기

# %%
# Maxout 
'''
class Maxout(layers.Layer):
    def __init__(self, units, pieces):
        super(Maxout, self).__init__()
        self.dense = layers.Dense(units*pieces, activation="relu")
        self.dropout = layers.Dropout(.5)    
        self.reshape = layers.Reshape((-1, pieces, units))
    
    def call(self, x):
        x = self.dense(x)
        x = self.dropout(x)
        x = self.reshape(x)
        return tf.math.reduce_max(x, axis=2)

print("✅")
'''
# Out:
# '\nclass Maxout(layers.Layer):\n    def __init__(self, units, pieces):\n        super(Maxout, self).__init__()\n        self.dense = layers.Dense(units*pieces, activation="relu")\n        self.dropout = layers.Dropout(.5)    \n        self.reshape = layers.Reshape((-1, pieces, units))\n    \n    def call(self, x):\n        x = self.dense(x)\n        x = self.dropout(x)\n        x = self.reshape(x)\n        return tf.math.reduce_max(x, axis=2)\n\nprint("✅")\n'

# %%
# cGAN Discriminator
'''
class DiscriminatorCGAN(Model):
    def __init__(self):
        super(DiscriminatorCGAN, self).__init__()
        self.flatten = layers.Flatten()
        
        self.image_block = Maxout(240, 5)
        self.label_block = Maxout(50, 5)
        self.combine_block = Maxout(240, 4)
        
        self.dense = layers.Dense(1, activation=None)
    
    def call(self, image, label):
        image = self.flatten(image)
        image = self.image_block(image)
        label = self.label_block(label)
        x = layers.Concatenate()([image, label])
        x = self.combine_block(x)
        return self.dense(x)
    
print("✅")
'''
# Out:
# '\nclass DiscriminatorCGAN(Model):\n    def __init__(self):\n        super(DiscriminatorCGAN, self).__init__()\n        self.flatten = layers.Flatten()\n        \n        self.image_block = Maxout(240, 5)\n        self.label_block = Maxout(50, 5)\n        self.combine_block = Maxout(240, 4)\n        \n        self.dense = layers.Dense(1, activation=None)\n    \n    def call(self, image, label):\n        image = self.flatten(image)\n        image = self.image_block(image)\n        label = self.label_block(label)\n        x = layers.Concatenate()([image, label])\n        x = self.combine_block(x)\n        return self.dense(x)\n    \nprint("✅")\n'

# %% [markdown]
# ### 3.1 Discriminator Block

# %%
# Discriminator Block

class DiscBlock(layers.Layer):
    def __init__(self, n_filters, stride=2, custom_pad=False, use_bn=True, act=True):
        super(DiscBlock, self).__init__()
        self.custom_pad = custom_pad
        self.use_bn = use_bn
        self.act = act
        
        if custom_pad:
            self.padding = layers.ZeroPadding2D()
            self.conv = layers.Conv2D(n_filters, 4, stride, "valid", use_bias=False)
        else:
            self.conv = layers.Conv2D(n_filters, 4, stride, "same", use_bias=False)
        
        self.batchnorm = layers.BatchNormalization() if use_bn else None
        self.lrelu = layers.LeakyReLU(0.2) if act else None
        
    def call(self, x):
        if self.custom_pad:
            x = self.padding(x)
            x = self.conv(x)
        else:
            x = self.conv(x)
                
        if self.use_bn:
            x = self.batchnorm(x)
            
        if self.act:
            x = self.lrelu(x)
        return x 

print("✅")
# Out:
# ✅

# %%
# 각 출력의 크기 확인

inputs = Input((128,128,32))
out = layers.ZeroPadding2D()(inputs)
out = layers.Conv2D(64, 4, 1, "valid", use_bias=False)(out)
out = layers.BatchNormalization()(out)
out = layers.LeakyReLU(0.2)(out)

Model(inputs, out).summary()
# Out:
# Model: "model_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_5 (InputLayer)         [(None, 128, 128, 32)]    0
# _________________________________________________________________
# zero_padding2d (ZeroPadding2 (None, 130, 130, 32)      0
# _________________________________________________________________
# conv2d_24 (Conv2D)           (None, 127, 127, 64)      32768
# _________________________________________________________________
# batch_normalization_45 (Batc (None, 127, 127, 64)      256
# _________________________________________________________________
# leaky_re_lu_24 (LeakyReLU)   (None, 127, 127, 64)      0
# =================================================================
# Total params: 33,024
# Trainable params: 32,896
# Non-trainable params: 128
# _________________________________________________________________

# %% [markdown]
# ### 3.2 Discriminator

# %%
# Discriminator 구현

class Discriminator(Model):
    def __init__(self):
        super(Discriminator, self).__init__()
        
        self.block1 = layers.Concatenate()
        self.block2 = DiscBlock(n_filters=64, stride=2, custom_pad=False, use_bn=False, act=True)
        self.block3 = DiscBlock(n_filters=128, stride=2, custom_pad=False, use_bn=True, act=True)
        self.block4 = DiscBlock(n_filters=256, stride=2, custom_pad=False, use_bn=True, act=True)
        self.block5 = DiscBlock(n_filters=512, stride=1, custom_pad=True, use_bn=True, act=True)
        self.block6 = DiscBlock(n_filters=1, stride=1, custom_pad=True, use_bn=False, act=False)
        self.sigmoid = layers.Activation("sigmoid")
        
        # filters = [64,128,256,512,1]
        # self.blocks = [layers.Concatenate()]
        # for i, f in enumerate(filters):
        #     self.blocks.append(DiscBlock(
        #         n_filters=f,
        #         strides=2 if i<3 else 1,
        #         custom_pad=False if i<3 else True,
        #         use_bn=False if i==0 and i==4 else True,
        #         act=True if i<4 else False
        #     ))
    
    def call(self, x, y):
        out = self.block1([x, y])
        out = self.block2(out)
        out = self.block3(out)
        out = self.block4(out)
        out = self.block5(out)
        out = self.block6(out)
        return self.sigmoid(out)
    
    def get_summary(self, x_shape=(256,256,3), y_shape=(256,256,3)):
        x, y = Input(x_shape), Input(y_shape) 
        return Model((x, y), self.call(x, y)).summary()
    
print("✅")
# Out:
# ✅

# %%
# Discriminator 모델 확인 

Discriminator().get_summary()
# Out:
# Model: "model_5"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_6 (InputLayer)            [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# input_7 (InputLayer)            [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 256, 256, 6)  0           input_6[0][0]
#                                                                  input_7[0][0]
# __________________________________________________________________________________________________
# disc_block (DiscBlock)          (None, 128, 128, 64) 6144        concatenate_7[0][0]
# __________________________________________________________________________________________________
# disc_block_1 (DiscBlock)        (None, 64, 64, 128)  131584      disc_block[0][0]
# __________________________________________________________________________________________________
# disc_block_2 (DiscBlock)        (None, 32, 32, 256)  525312      disc_block_1[0][0]
# __________________________________________________________________________________________________
# disc_block_3 (DiscBlock)        (None, 31, 31, 512)  2099200     disc_block_2[0][0]
# __________________________________________________________________________________________________
# disc_block_4 (DiscBlock)        (None, 30, 30, 1)    8192        disc_block_3[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 30, 30, 1)    0           disc_block_4[0][0]
# ==================================================================================================
# Total params: 2,770,432
# Trainable params: 2,768,640
# Non-trainable params: 1,792
# __________________________________________________________________________________________________

# %% [markdown]
# ### 3.3 출력 확인 및 시각화

# %%
x = tf.random.normal([1,256,256,3])
y = tf.random.uniform([1,256,256,3])

disc_out = Discriminator()(x, y)
plt.imshow(disc_out[0, ... ,0])
plt.colorbar()

# %% [markdown]
# ## 4. 모델 학습

# %% [markdown]
# ### 4.1 loss function

# %%
from tensorflow.keras import losses

bce = losses.BinaryCrossentropy(from_logits=False)
mae = losses.MeanAbsoluteError()

def get_gene_loss(fake_output, real_output, fake_disc):
    l1_loss = mae(real_output, fake_output)
    gene_loss = bce(tf.ones_like(fake_disc), fake_disc)
    return gene_loss, l1_loss

def get_disc_loss(fake_disc, real_disc):
    return bce(tf.zeros_like(fake_disc), fake_disc) + bce(tf.ones_like(real_disc), real_disc)

print("✅")
# Out:
# ✅

# %% [markdown]
# ### 4.2 optimizer

# %%
from tensorflow.keras import optimizers

gene_opt = optimizers.Adam(2e-4, beta_1=.5, beta_2=.999)
disc_opt = optimizers.Adam(2e-4, beta_1=.5, beta_2=.999)

print("✅")
# Out:
# ✅

# %% [markdown]
# ### 4.3 train step

# %%
@tf.function
def train_step(sketch, real_colored):
    with tf.GradientTape() as gene_tape, tf.GradientTape() as disc_tape:
        # Generator 예측
        fake_colored = generator(sketch, training=True)
        # Discriminator 예측
        fake_disc = discriminator(sketch, fake_colored, training=True)
        real_disc = discriminator(sketch, real_colored, training=True)
        # Generator 손실 계산
        gene_loss, l1_loss = get_gene_loss(fake_colored, real_colored, fake_disc)
        gene_total_loss = gene_loss + (100 * l1_loss) ## <===== L1 손실 반영 λ=100
        # Discrminator 손실 계산
        disc_loss = get_disc_loss(fake_disc, real_disc)
                
    gene_gradient = gene_tape.gradient(gene_total_loss, generator.trainable_variables)
    disc_gradient = disc_tape.gradient(disc_loss, discriminator.trainable_variables)
    
    gene_opt.apply_gradients(zip(gene_gradient, generator.trainable_variables))
    disc_opt.apply_gradients(zip(disc_gradient, discriminator.trainable_variables))
    return gene_loss, l1_loss, disc_loss

print("✅")
# Out:
# ✅

# %% [markdown]
# ### 4.4 model fit

# %%
EPOCHS = 30

generator = UNetGenerator()
discriminator = Discriminator()

for epoch in range(1, EPOCHS+1):
    for i, (sketch, colored) in enumerate(train_images):
        g_loss, l1_loss, d_loss = train_step(sketch, colored)
                
        # 10회 반복마다 손실을 출력합니다.
        if (i+1) % 10 == 0:
            print(f"EPOCH[{epoch}] - STEP[{i+1}] \
                    \nGenerator_loss:{g_loss.numpy():.4f} \
                    \nL1_loss:{l1_loss.numpy():.4f} \
                    \nDiscriminator_loss:{d_loss.numpy():.4f}", end="\n\n")
# Out:
# EPOCH[1] - STEP[10]
# Generator_loss:0.8337
# L1_loss:0.3365
# Discriminator_loss:1.2320
#
# EPOCH[1] - STEP[20]
# Generator_loss:1.0439
# L1_loss:0.2934
# Discriminator_loss:1.1721
#
# EPOCH[1] - STEP[30]
# Generator_loss:1.1180
# L1_loss:0.2731
# Discriminator_loss:0.9644
#
# EPOCH[1] - STEP[40]
# Generator_loss:1.5939
# L1_loss:0.2792
# Discriminator_loss:0.7866
#
# EPOCH[1] - STEP[50]
# Generator_loss:1.6188
# L1_loss:0.2637
# Discriminator_loss:0.5558
#
# EPOCH[1] - STEP[60]
# Generator_loss:1.5098
# L1_loss:0.2427
# Discriminator_loss:0.7868
#
# EPOCH[1] - STEP[70]
# Generator_loss:1.5659
# L1_loss:0.2980
# Discriminator_loss:0.4872
#
# EPOCH[1] - STEP[80]
# Generator_loss:1.9553
# L1_loss:0.2730
# Discriminator_loss:0.9634
#
# EPOCH[1] - STEP[90]
# Generator_loss:2.2396
# L1_loss:0.2420
# Discriminator_loss:0.3019
#
# EPOCH[1] - STEP[100]
# Generator_loss:1.8030
# L1_loss:0.2505
# Discriminator_loss:1.1714
#
# EPOCH[1] - STEP[110]
# Generator_loss:1.5860
# L1_loss:0.2166
# Discriminator_loss:1.0166
#
# EPOCH[1] - STEP[120]
# Generator_loss:1.5816
# L1_loss:0.2168
# Discriminator_loss:0.5655
#
# EPOCH[1] - STEP[130]
# Generator_loss:0.8517
# L1_loss:0.2012
# Discriminator_loss:1.0439
#
# EPOCH[1] - STEP[140]
# Generator_loss:0.8738
# L1_loss:0.2287
# Discriminator_loss:1.4656
#
# EPOCH[1] - STEP[150]
# Generator_loss:1.8187
# L1_loss:0.2213
# Discriminator_loss:0.6715
#
# EPOCH[1] - STEP[160]
# Generator_loss:1.0620
# L1_loss:0.2524
# Discriminator_loss:0.7495
#
# EPOCH[1] - STEP[170]
# Generator_loss:1.9262
# L1_loss:0.2068
# Discriminator_loss:0.7856
#
# EPOCH[1] - STEP[180]
# Generator_loss:1.9258
# L1_loss:0.2583
# Discriminator_loss:0.4303
#
# EPOCH[1] - STEP[190]
# Generator_loss:2.4772
# L1_loss:0.2861
# Discriminator_loss:0.3889
#
# EPOCH[1] - STEP[200]
# Generator_loss:1.4123
# L1_loss:0.2296
# Discriminator_loss:1.1905
#
# EPOCH[1] - STEP[210]
# Generator_loss:2.2793
# L1_loss:0.2368
# Discriminator_loss:0.7087
#
# EPOCH[1] - STEP[220]
# Generator_loss:1.3111
# L1_loss:0.2089
# Discriminator_loss:0.5807
#
# EPOCH[1] - STEP[230]
# Generator_loss:2.3803
# L1_loss:0.2659
# Discriminator_loss:0.4483
#
# EPOCH[1] - STEP[240]
# Generator_loss:1.1687
# L1_loss:0.2513
# Discriminator_loss:1.3379
#
# EPOCH[1] - STEP[250]
# Generator_loss:2.0395
# L1_loss:0.2175
# Discriminator_loss:0.5759
#
# EPOCH[2] - STEP[10]
# Generator_loss:1.1464
# L1_loss:0.2363
# Discriminator_loss:1.2182
#
# EPOCH[2] - STEP[20]
# Generator_loss:2.1190
# L1_loss:0.2276
# Discriminator_loss:0.5342
#
# EPOCH[2] - STEP[30]
# Generator_loss:0.9598
# L1_loss:0.2370
# Discriminator_loss:0.8710
#
# EPOCH[2] - STEP[40]
# Generator_loss:0.3895
# L1_loss:0.2076
# Discriminator_loss:1.6078
#
# EPOCH[2] - STEP[50]
# Generator_loss:3.0017
# L1_loss:0.2102
# Discriminator_loss:0.5719
#
# EPOCH[2] - STEP[60]
# Generator_loss:1.5508
# L1_loss:0.2735
# Discriminator_loss:0.5943
#
# EPOCH[2] - STEP[70]
# Generator_loss:0.6147
# L1_loss:0.2274
# Discriminator_loss:1.1595
#
# EPOCH[2] - STEP[80]
# Generator_loss:1.3186
# L1_loss:0.2045
# Discriminator_loss:0.8915
#
# EPOCH[2] - STEP[90]
# Generator_loss:1.3005
# L1_loss:0.2570
# Discriminator_loss:0.4727
#
# EPOCH[2] - STEP[100]
# Generator_loss:0.9012
# L1_loss:0.2648
# Discriminator_loss:0.8569
#
# EPOCH[2] - STEP[110]
# Generator_loss:2.1764
# L1_loss:0.1931
# Discriminator_loss:0.6226
#
# EPOCH[2] - STEP[120]
# Generator_loss:1.9865
# L1_loss:0.2224
# Discriminator_loss:0.5481
#
# EPOCH[2] - STEP[130]
# Generator_loss:1.5708
# L1_loss:0.2201
# Discriminator_loss:1.1493
#
# EPOCH[2] - STEP[140]
# Generator_loss:1.9345
# L1_loss:0.2508
# Discriminator_loss:0.3273
#
# EPOCH[2] - STEP[150]
# Generator_loss:1.7591
# L1_loss:0.1954
# Discriminator_loss:0.7495
#
# EPOCH[2] - STEP[160]
# Generator_loss:1.5064
# L1_loss:0.2328
# Discriminator_loss:0.6056
#
# EPOCH[2] - STEP[170]
# Generator_loss:2.2701
# L1_loss:0.2667
# Discriminator_loss:0.6626
#
# EPOCH[2] - STEP[180]
# Generator_loss:1.6124
# L1_loss:0.2444
# Discriminator_loss:0.5059
#
# EPOCH[2] - STEP[190]
# Generator_loss:2.1379
# L1_loss:0.2396
# Discriminator_loss:0.9550
#
# EPOCH[2] - STEP[200]
# Generator_loss:0.9400
# L1_loss:0.2175
# Discriminator_loss:0.8542
#
# EPOCH[2] - STEP[210]
# Generator_loss:1.9329
# L1_loss:0.1951
# Discriminator_loss:0.7100
#
# EPOCH[2] - STEP[220]
# Generator_loss:2.1638
# L1_loss:0.2297
# Discriminator_loss:0.7342
#
# EPOCH[2] - STEP[230]
# Generator_loss:1.6312
# L1_loss:0.2064
# Discriminator_loss:0.5432
#
# EPOCH[2] - STEP[240]
# Generator_loss:1.6541
# L1_loss:0.1953
# Discriminator_loss:0.7764
#
# EPOCH[2] - STEP[250]
# Generator_loss:1.3840
# L1_loss:0.2110
# Discriminator_loss:0.5087
#
# EPOCH[3] - STEP[10]
# Generator_loss:1.1446
# L1_loss:0.2201
# Discriminator_loss:1.0891
#
# EPOCH[3] - STEP[20]
# Generator_loss:1.9297
# L1_loss:0.2266
# Discriminator_loss:0.6927
#
# EPOCH[3] - STEP[30]
# Generator_loss:2.0083
# L1_loss:0.1770
# Discriminator_loss:0.5515
#
# EPOCH[3] - STEP[40]
# Generator_loss:0.8425
# L1_loss:0.1786
# Discriminator_loss:1.4447
#
# EPOCH[3] - STEP[50]
# Generator_loss:1.3029
# L1_loss:0.1877
# Discriminator_loss:0.7448
#
# EPOCH[3] - STEP[60]
# Generator_loss:2.5014
# L1_loss:0.2085
# Discriminator_loss:0.3702
#
# EPOCH[3] - STEP[70]
# Generator_loss:1.4376
# L1_loss:0.2462
# Discriminator_loss:0.5197
#
# EPOCH[3] - STEP[80]
# Generator_loss:1.6914
# L1_loss:0.1824
# Discriminator_loss:0.6942
#
# EPOCH[3] - STEP[90]
# Generator_loss:1.8636
# L1_loss:0.1968
# Discriminator_loss:0.5754
#
# EPOCH[3] - STEP[100]
# Generator_loss:1.5271
# L1_loss:0.2195
# Discriminator_loss:0.4198
#
# EPOCH[3] - STEP[110]
# Generator_loss:2.7794
# L1_loss:0.1893
# Discriminator_loss:2.9219
#
# EPOCH[3] - STEP[120]
# Generator_loss:1.5699
# L1_loss:0.2093
# Discriminator_loss:0.4740
#
# EPOCH[3] - STEP[130]
# Generator_loss:1.8397
# L1_loss:0.1781
# Discriminator_loss:1.1033
#
# EPOCH[3] - STEP[140]
# Generator_loss:1.8887
# L1_loss:0.1716
# Discriminator_loss:0.5800
#
# EPOCH[3] - STEP[150]
# Generator_loss:2.1518
# L1_loss:0.1626
# Discriminator_loss:0.5775
#
# EPOCH[3] - STEP[160]
# Generator_loss:1.2233
# L1_loss:0.2096
# Discriminator_loss:0.6663
#
# EPOCH[3] - STEP[170]
# Generator_loss:1.1106
# L1_loss:0.2217
# Discriminator_loss:1.0594
#
# EPOCH[3] - STEP[180]
# Generator_loss:1.0447
# L1_loss:0.2053
# Discriminator_loss:0.6770
#
# EPOCH[3] - STEP[190]
# Generator_loss:2.7020
# L1_loss:0.1809
# Discriminator_loss:1.8482
#
# EPOCH[3] - STEP[200]
# Generator_loss:1.9392
# L1_loss:0.1751
# Discriminator_loss:0.7340
#
# EPOCH[3] - STEP[210]
# Generator_loss:1.8419
# L1_loss:0.2074
# Discriminator_loss:0.3838
#
# EPOCH[3] - STEP[220]
# Generator_loss:0.8658
# L1_loss:0.1940
# Discriminator_loss:0.8199
#
# EPOCH[3] - STEP[230]
# Generator_loss:1.3736
# L1_loss:0.2127
# Discriminator_loss:0.6826
#
# EPOCH[3] - STEP[240]
# Generator_loss:1.0203
# L1_loss:0.1996
# Discriminator_loss:0.8652
#
# EPOCH[3] - STEP[250]
# Generator_loss:1.1063
# L1_loss:0.2335
# Discriminator_loss:0.7924
#
# EPOCH[4] - STEP[10]
# Generator_loss:1.7966
# L1_loss:0.1903
# Discriminator_loss:0.6421
#
# EPOCH[4] - STEP[20]
# Generator_loss:1.5463
# L1_loss:0.2270
# Discriminator_loss:0.4245
#
# EPOCH[4] - STEP[30]
# Generator_loss:1.9861
# L1_loss:0.1776
# Discriminator_loss:0.9782
#
# EPOCH[4] - STEP[40]
# Generator_loss:0.7813
# L1_loss:0.2519
# Discriminator_loss:0.8835
#
# EPOCH[4] - STEP[50]
# Generator_loss:0.9749
# L1_loss:0.1812
# Discriminator_loss:0.7780
#
# EPOCH[4] - STEP[60]
# Generator_loss:1.2877
# L1_loss:0.1655
# Discriminator_loss:1.0868
#
# EPOCH[4] - STEP[70]
# Generator_loss:1.1952
# L1_loss:0.1767
# Discriminator_loss:0.5860
#
# EPOCH[4] - STEP[80]
# Generator_loss:1.9666
# L1_loss:0.2411
# Discriminator_loss:0.4302
#
# EPOCH[4] - STEP[90]
# Generator_loss:1.3651
# L1_loss:0.2202
# Discriminator_loss:0.8413
#
# EPOCH[4] - STEP[100]
# Generator_loss:0.7073
# L1_loss:0.2071
# Discriminator_loss:1.3612
#
# EPOCH[4] - STEP[110]
# Generator_loss:2.5406
# L1_loss:0.2489
# Discriminator_loss:0.4719
#
# EPOCH[4] - STEP[120]
# Generator_loss:2.2386
# L1_loss:0.1943
# Discriminator_loss:1.4622
#
# EPOCH[4] - STEP[130]
# Generator_loss:1.3911
# L1_loss:0.2064
# Discriminator_loss:0.5633
#
# EPOCH[4] - STEP[140]
# Generator_loss:2.1423
# L1_loss:0.1489
# Discriminator_loss:0.4875
#
# EPOCH[4] - STEP[150]
# Generator_loss:1.2909
# L1_loss:0.1710
# Discriminator_loss:0.5690
#
# EPOCH[4] - STEP[160]
# Generator_loss:2.4133
# L1_loss:0.1602
# Discriminator_loss:0.8590
#
# EPOCH[4] - STEP[170]
# Generator_loss:1.6254
# L1_loss:0.2092
# Discriminator_loss:0.9932
#
# EPOCH[4] - STEP[180]
# Generator_loss:3.3725
# L1_loss:0.1756
# Discriminator_loss:1.6218
#
# EPOCH[4] - STEP[190]
# Generator_loss:0.8434
# L1_loss:0.1990
# Discriminator_loss:0.7792
#
# EPOCH[4] - STEP[200]
# Generator_loss:2.2023
# L1_loss:0.1960
# Discriminator_loss:1.0289
#
# EPOCH[4] - STEP[210]
# Generator_loss:0.8298
# L1_loss:0.1836
# Discriminator_loss:0.9965
#
# EPOCH[4] - STEP[220]
# Generator_loss:2.3032
# L1_loss:0.1568
# Discriminator_loss:1.2532
#
# EPOCH[4] - STEP[230]
# Generator_loss:2.0468
# L1_loss:0.1615
# Discriminator_loss:0.9144
#
# EPOCH[4] - STEP[240]
# Generator_loss:1.5400
# L1_loss:0.2161
# Discriminator_loss:0.4664
#
# EPOCH[4] - STEP[250]
# Generator_loss:2.3141
# L1_loss:0.2109
# Discriminator_loss:0.7713
#
# EPOCH[5] - STEP[10]
# Generator_loss:1.2301
# L1_loss:0.2260
# Discriminator_loss:0.6406
#
# EPOCH[5] - STEP[20]
# Generator_loss:2.2785
# L1_loss:0.2337
# Discriminator_loss:0.5108
#
# EPOCH[5] - STEP[30]
# Generator_loss:1.4079
# L1_loss:0.2267
# Discriminator_loss:0.4518
#
# EPOCH[5] - STEP[40]
# Generator_loss:0.6426
# L1_loss:0.1985
# Discriminator_loss:1.8984
#
# EPOCH[5] - STEP[50]
# Generator_loss:1.4824
# L1_loss:0.1953
# Discriminator_loss:0.4554
#
# EPOCH[5] - STEP[60]
# Generator_loss:1.7870
# L1_loss:0.1739
# Discriminator_loss:1.1809
#
# EPOCH[5] - STEP[70]
# Generator_loss:2.0023
# L1_loss:0.2205
# Discriminator_loss:0.5634
#
# EPOCH[5] - STEP[80]
# Generator_loss:1.2070
# L1_loss:0.1577
# Discriminator_loss:0.6965
#
# EPOCH[5] - STEP[90]
# Generator_loss:2.7914
# L1_loss:0.2237
# Discriminator_loss:0.4218
#
# EPOCH[5] - STEP[100]
# Generator_loss:1.2946
# L1_loss:0.2181
# Discriminator_loss:0.7191
#
# EPOCH[5] - STEP[110]
# Generator_loss:1.9594
# L1_loss:0.1802
# Discriminator_loss:0.8833
#
# EPOCH[5] - STEP[120]
# Generator_loss:1.9648
# L1_loss:0.1950
# Discriminator_loss:0.3640
#
# EPOCH[5] - STEP[130]
# Generator_loss:2.6072
# L1_loss:0.2002
# Discriminator_loss:0.7100
#
# EPOCH[5] - STEP[140]
# Generator_loss:1.5520
# L1_loss:0.1831
# Discriminator_loss:1.2624
#
# EPOCH[5] - STEP[150]
# Generator_loss:1.8618
# L1_loss:0.1846
# Discriminator_loss:0.4039
#
# EPOCH[5] - STEP[160]
# Generator_loss:1.3708
# L1_loss:0.1633
# Discriminator_loss:0.8960
#
# EPOCH[5] - STEP[170]
# Generator_loss:2.3595
# L1_loss:0.1958
# Discriminator_loss:0.6188
#
# EPOCH[5] - STEP[180]
# Generator_loss:0.9311
# L1_loss:0.2028
# Discriminator_loss:0.9541
#
# EPOCH[5] - STEP[190]
# Generator_loss:2.4523
# L1_loss:0.2207
# Discriminator_loss:0.5266
#
# EPOCH[5] - STEP[200]
# Generator_loss:0.9404
# L1_loss:0.1828
# Discriminator_loss:1.1529
#
# EPOCH[5] - STEP[210]
# Generator_loss:2.2570
# L1_loss:0.2315
# Discriminator_loss:0.3301
#
# EPOCH[5] - STEP[220]
# Generator_loss:0.7416
# L1_loss:0.1534
# Discriminator_loss:1.3994
#
# EPOCH[5] - STEP[230]
# Generator_loss:1.1415
# L1_loss:0.1871
# Discriminator_loss:0.5622
#
# EPOCH[5] - STEP[240]
# Generator_loss:1.5327
# L1_loss:0.1542
# Discriminator_loss:0.5358
#
# EPOCH[5] - STEP[250]
# Generator_loss:1.6323
# L1_loss:0.1632
# Discriminator_loss:0.7620
#
# EPOCH[6] - STEP[10]
# Generator_loss:0.8089
# L1_loss:0.2065
# Discriminator_loss:0.7732
#
# EPOCH[6] - STEP[20]
# Generator_loss:0.1577
# L1_loss:0.1843
# Discriminator_loss:2.2697
#
# EPOCH[6] - STEP[30]
# Generator_loss:1.5211
# L1_loss:0.1926
# Discriminator_loss:0.6538
#
# EPOCH[6] - STEP[40]
# Generator_loss:0.6242
# L1_loss:0.1607
# Discriminator_loss:1.1215
#
# EPOCH[6] - STEP[50]
# Generator_loss:3.0431
# L1_loss:0.2224
# Discriminator_loss:0.6937
#
# EPOCH[6] - STEP[60]
# Generator_loss:1.6779
# L1_loss:0.1971
# Discriminator_loss:0.4823
#
# EPOCH[6] - STEP[70]
# Generator_loss:0.6065
# L1_loss:0.1665
# Discriminator_loss:1.2073
#
# EPOCH[6] - STEP[80]
# Generator_loss:0.5360
# L1_loss:0.2037
# Discriminator_loss:1.0984
#
# EPOCH[6] - STEP[90]
# Generator_loss:1.6762
# L1_loss:0.1817
# Discriminator_loss:0.5495
#
# EPOCH[6] - STEP[100]
# Generator_loss:1.9990
# L1_loss:0.2077
# Discriminator_loss:0.3474
#
# EPOCH[6] - STEP[110]
# Generator_loss:1.3546
# L1_loss:0.2003
# Discriminator_loss:0.5102
#
# EPOCH[6] - STEP[120]
# Generator_loss:2.5786
# L1_loss:0.1670
# Discriminator_loss:1.0270
#
# EPOCH[6] - STEP[130]
# Generator_loss:1.4208
# L1_loss:0.1950
# Discriminator_loss:0.5596
#
# EPOCH[6] - STEP[140]
# Generator_loss:2.3839
# L1_loss:0.1739
# Discriminator_loss:0.4743
#
# EPOCH[6] - STEP[150]
# Generator_loss:2.5189
# L1_loss:0.2251
# Discriminator_loss:1.7091
#
# EPOCH[6] - STEP[160]
# Generator_loss:1.5072
# L1_loss:0.1913
# Discriminator_loss:0.5839
#
# EPOCH[6] - STEP[170]
# Generator_loss:0.9543
# L1_loss:0.2196
# Discriminator_loss:0.6809
#
# EPOCH[6] - STEP[180]
# Generator_loss:0.7890
# L1_loss:0.2032
# Discriminator_loss:0.9514
#
# EPOCH[6] - STEP[190]
# Generator_loss:2.5863
# L1_loss:0.2733
# Discriminator_loss:0.2883
#
# EPOCH[6] - STEP[200]
# Generator_loss:1.1616
# L1_loss:0.2162
# Discriminator_loss:0.5330
#
# EPOCH[6] - STEP[210]
# Generator_loss:0.8376
# L1_loss:0.1824
# Discriminator_loss:0.8841
#
# EPOCH[6] - STEP[220]
# Generator_loss:1.2148
# L1_loss:0.1351
# Discriminator_loss:1.1205
#
# EPOCH[6] - STEP[230]
# Generator_loss:2.6474
# L1_loss:0.2046
# Discriminator_loss:1.0703
#
# EPOCH[6] - STEP[240]
# Generator_loss:1.5605
# L1_loss:0.1842
# Discriminator_loss:0.4170
#
# EPOCH[6] - STEP[250]
# Generator_loss:0.6518
# L1_loss:0.1830
# Discriminator_loss:1.0009
#
# EPOCH[7] - STEP[10]
# Generator_loss:0.4842
# L1_loss:0.1861
# Discriminator_loss:2.0764
#
# EPOCH[7] - STEP[20]
# Generator_loss:1.7671
# L1_loss:0.2056
# Discriminator_loss:0.8836
#
# EPOCH[7] - STEP[30]
# Generator_loss:1.6841
# L1_loss:0.2147
# Discriminator_loss:0.4840
#
# EPOCH[7] - STEP[40]
# Generator_loss:1.2893
# L1_loss:0.1786
# Discriminator_loss:0.5140
#
# EPOCH[7] - STEP[50]
# Generator_loss:0.5501
# L1_loss:0.1754
# Discriminator_loss:1.3047
#
# EPOCH[7] - STEP[60]
# Generator_loss:1.9524
# L1_loss:0.2004
# Discriminator_loss:0.4531
#
# EPOCH[7] - STEP[70]
# Generator_loss:1.3300
# L1_loss:0.1737
# Discriminator_loss:0.4925
#
# EPOCH[7] - STEP[80]
# Generator_loss:0.9885
# L1_loss:0.1598
# Discriminator_loss:0.9271
#
# EPOCH[7] - STEP[90]
# Generator_loss:0.9892
# L1_loss:0.1582
# Discriminator_loss:0.9622
#
# EPOCH[7] - STEP[100]
# Generator_loss:2.7428
# L1_loss:0.2202
# Discriminator_loss:0.2640
#
# EPOCH[7] - STEP[110]
# Generator_loss:1.9099
# L1_loss:0.1845
# Discriminator_loss:0.3172
#
# EPOCH[7] - STEP[120]
# Generator_loss:2.7353
# L1_loss:0.2119
# Discriminator_loss:1.5213
#
# EPOCH[7] - STEP[130]
# Generator_loss:2.1569
# L1_loss:0.1881
# Discriminator_loss:0.6181
#
# EPOCH[7] - STEP[140]
# Generator_loss:0.4986
# L1_loss:0.2062
# Discriminator_loss:1.3301
#
# EPOCH[7] - STEP[150]
# Generator_loss:2.1337
# L1_loss:0.1743
# Discriminator_loss:1.4351
#
# EPOCH[7] - STEP[160]
# Generator_loss:1.0497
# L1_loss:0.1994
# Discriminator_loss:0.7723
#
# EPOCH[7] - STEP[170]
# Generator_loss:2.0603
# L1_loss:0.1816
# Discriminator_loss:1.7117
#
# EPOCH[7] - STEP[180]
# Generator_loss:0.8933
# L1_loss:0.1799
# Discriminator_loss:0.7752
#
# EPOCH[7] - STEP[190]
# Generator_loss:1.5984
# L1_loss:0.2117
# Discriminator_loss:0.3401
#
# EPOCH[7] - STEP[200]
# Generator_loss:3.1027
# L1_loss:0.1503
# Discriminator_loss:1.6629
#
# EPOCH[7] - STEP[210]
# Generator_loss:1.5250
# L1_loss:0.2687
# Discriminator_loss:0.4041
#
# EPOCH[7] - STEP[220]
# Generator_loss:2.6422
# L1_loss:0.2100
# Discriminator_loss:0.2094
#
# EPOCH[7] - STEP[230]
# Generator_loss:0.8111
# L1_loss:0.1999
# Discriminator_loss:0.8729
#
# EPOCH[7] - STEP[240]
# Generator_loss:2.9667
# L1_loss:0.2161
# Discriminator_loss:1.3038
#
# EPOCH[7] - STEP[250]
# Generator_loss:2.1839
# L1_loss:0.1739
# Discriminator_loss:0.7510
#
# EPOCH[8] - STEP[10]
# Generator_loss:0.7372
# L1_loss:0.1746
# Discriminator_loss:0.8782
#
# EPOCH[8] - STEP[20]
# Generator_loss:1.1701
# L1_loss:0.2227
# Discriminator_loss:0.9157
#
# EPOCH[8] - STEP[30]
# Generator_loss:1.8569
# L1_loss:0.1985
# Discriminator_loss:0.3433
#
# EPOCH[8] - STEP[40]
# Generator_loss:0.5785
# L1_loss:0.1675
# Discriminator_loss:1.2384
#
# EPOCH[8] - STEP[50]
# Generator_loss:1.3667
# L1_loss:0.1688
# Discriminator_loss:0.7692
#
# EPOCH[8] - STEP[60]
# Generator_loss:1.7469
# L1_loss:0.2001
# Discriminator_loss:0.5862
#
# EPOCH[8] - STEP[70]
# Generator_loss:1.7085
# L1_loss:0.1877
# Discriminator_loss:1.3979
#
# EPOCH[8] - STEP[80]
# Generator_loss:2.9459
# L1_loss:0.1475
# Discriminator_loss:1.4007
#
# EPOCH[8] - STEP[90]
# Generator_loss:1.6230
# L1_loss:0.2079
# Discriminator_loss:0.4531
#
# EPOCH[8] - STEP[100]
# Generator_loss:0.6591
# L1_loss:0.1789
# Discriminator_loss:1.0085
#
# EPOCH[8] - STEP[110]
# Generator_loss:0.8403
# L1_loss:0.1849
# Discriminator_loss:0.7195
#
# EPOCH[8] - STEP[120]
# Generator_loss:2.0807
# L1_loss:0.1783
# Discriminator_loss:0.8396
#
# EPOCH[8] - STEP[130]
# Generator_loss:0.7929
# L1_loss:0.1730
# Discriminator_loss:0.7918
#
# EPOCH[8] - STEP[140]
# Generator_loss:0.7131
# L1_loss:0.1785
# Discriminator_loss:0.8190
#
# EPOCH[8] - STEP[150]
# Generator_loss:1.6394
# L1_loss:0.1475
# Discriminator_loss:1.4419
#
# EPOCH[8] - STEP[160]
# Generator_loss:1.9462
# L1_loss:0.1815
# Discriminator_loss:0.6785
#
# EPOCH[8] - STEP[170]
# Generator_loss:2.1537
# L1_loss:0.2212
# Discriminator_loss:0.5808
#
# EPOCH[8] - STEP[180]
# Generator_loss:2.8119
# L1_loss:0.1545
# Discriminator_loss:0.9316
#
# EPOCH[8] - STEP[190]
# Generator_loss:2.0926
# L1_loss:0.1723
# Discriminator_loss:1.0589
#
# EPOCH[8] - STEP[200]
# Generator_loss:1.6112
# L1_loss:0.2010
# Discriminator_loss:1.1868
#
# EPOCH[8] - STEP[210]
# Generator_loss:2.1047
# L1_loss:0.1691
# Discriminator_loss:0.4473
#
# EPOCH[8] - STEP[220]
# Generator_loss:1.8933
# L1_loss:0.2091
# Discriminator_loss:0.3389
#
# EPOCH[8] - STEP[230]
# Generator_loss:2.3279
# L1_loss:0.1587
# Discriminator_loss:0.9503
#
# EPOCH[8] - STEP[240]
# Generator_loss:3.1328
# L1_loss:0.1575
# Discriminator_loss:1.3543
#
# EPOCH[8] - STEP[250]
# Generator_loss:1.8692
# L1_loss:0.1906
# Discriminator_loss:0.5246
#
# EPOCH[9] - STEP[10]
# Generator_loss:1.9793
# L1_loss:0.1758
# Discriminator_loss:1.5158
#
# EPOCH[9] - STEP[20]
# Generator_loss:0.7323
# L1_loss:0.1697
# Discriminator_loss:0.9553
#
# EPOCH[9] - STEP[30]
# Generator_loss:1.2078
# L1_loss:0.1869
# Discriminator_loss:0.6674
#
# EPOCH[9] - STEP[40]
# Generator_loss:1.4267
# L1_loss:0.1880
# Discriminator_loss:0.4873
#
# EPOCH[9] - STEP[50]
# Generator_loss:1.7694
# L1_loss:0.1672
# Discriminator_loss:0.5736
#
# EPOCH[9] - STEP[60]
# Generator_loss:1.8605
# L1_loss:0.2029
# Discriminator_loss:0.3201
#
# EPOCH[9] - STEP[70]
# Generator_loss:1.0848
# L1_loss:0.2187
# Discriminator_loss:0.8199
#
# EPOCH[9] - STEP[80]
# Generator_loss:2.0473
# L1_loss:0.1928
# Discriminator_loss:0.5407
#
# EPOCH[9] - STEP[90]
# Generator_loss:1.0389
# L1_loss:0.1573
# Discriminator_loss:0.8526
#
# EPOCH[9] - STEP[100]
# Generator_loss:1.0334
# L1_loss:0.1706
# Discriminator_loss:1.0816
#
# EPOCH[9] - STEP[110]
# Generator_loss:2.4472
# L1_loss:0.1613
# Discriminator_loss:0.4672
#
# EPOCH[9] - STEP[120]
# Generator_loss:2.3462
# L1_loss:0.1743
# Discriminator_loss:0.3220
#
# EPOCH[9] - STEP[130]
# Generator_loss:0.3426
# L1_loss:0.2153
# Discriminator_loss:1.5991
#
# EPOCH[9] - STEP[140]
# Generator_loss:0.4051
# L1_loss:0.1725
# Discriminator_loss:1.5544
#
# EPOCH[9] - STEP[150]
# Generator_loss:0.8130
# L1_loss:0.1960
# Discriminator_loss:0.7850
#
# EPOCH[9] - STEP[160]
# Generator_loss:2.8204
# L1_loss:0.2208
# Discriminator_loss:0.2023
#
# EPOCH[9] - STEP[170]
# Generator_loss:1.1061
# L1_loss:0.2001
# Discriminator_loss:0.8437
#
# EPOCH[9] - STEP[180]
# Generator_loss:1.2217
# L1_loss:0.2680
# Discriminator_loss:0.4835
#
# EPOCH[9] - STEP[190]
# Generator_loss:1.5324
# L1_loss:0.2240
# Discriminator_loss:0.5438
#
# EPOCH[9] - STEP[200]
# Generator_loss:0.9186
# L1_loss:0.2174
# Discriminator_loss:1.2899
#
# EPOCH[9] - STEP[210]
# Generator_loss:1.2793
# L1_loss:0.1883
# Discriminator_loss:0.5532
#
# EPOCH[9] - STEP[220]
# Generator_loss:2.3522
# L1_loss:0.1837
# Discriminator_loss:0.7775
#
# EPOCH[9] - STEP[230]
# Generator_loss:1.3801
# L1_loss:0.1496
# Discriminator_loss:0.7628
#
# EPOCH[9] - STEP[240]
# Generator_loss:2.5026
# L1_loss:0.1693
# Discriminator_loss:0.5390
#
# EPOCH[9] - STEP[250]
# Generator_loss:1.1507
# L1_loss:0.1545
# Discriminator_loss:0.9048
#
# EPOCH[10] - STEP[10]
# Generator_loss:1.0446
# L1_loss:0.1591
# Discriminator_loss:0.9688
#
# EPOCH[10] - STEP[20]
# Generator_loss:1.5493
# L1_loss:0.1478
# Discriminator_loss:1.6770
#
# EPOCH[10] - STEP[30]
# Generator_loss:2.2908
# L1_loss:0.1587
# Discriminator_loss:0.9895
#
# EPOCH[10] - STEP[40]
# Generator_loss:1.0967
# L1_loss:0.1651
# Discriminator_loss:0.6780
#
# EPOCH[10] - STEP[50]
# Generator_loss:2.7827
# L1_loss:0.1907
# Discriminator_loss:1.0199
#
# EPOCH[10] - STEP[60]
# Generator_loss:1.6318
# L1_loss:0.1918
# Discriminator_loss:1.2420
#
# EPOCH[10] - STEP[70]
# Generator_loss:1.2215
# L1_loss:0.2470
# Discriminator_loss:0.5525
#
# EPOCH[10] - STEP[80]
# Generator_loss:2.4087
# L1_loss:0.1827
# Discriminator_loss:0.8045
#
# EPOCH[10] - STEP[90]
# Generator_loss:2.2094
# L1_loss:0.1518
# Discriminator_loss:0.5842
#
# EPOCH[10] - STEP[100]
# Generator_loss:1.4416
# L1_loss:0.1663
# Discriminator_loss:0.7777
#
# EPOCH[10] - STEP[110]
# Generator_loss:2.4192
# L1_loss:0.1877
# Discriminator_loss:0.4259
#
# EPOCH[10] - STEP[120]
# Generator_loss:2.0974
# L1_loss:0.1904
# Discriminator_loss:0.5602
#
# EPOCH[10] - STEP[130]
# Generator_loss:1.6798
# L1_loss:0.1988
# Discriminator_loss:0.4442
#
# EPOCH[10] - STEP[140]
# Generator_loss:1.3708
# L1_loss:0.1493
# Discriminator_loss:1.1057
#
# EPOCH[10] - STEP[150]
# Generator_loss:2.3423
# L1_loss:0.1614
# Discriminator_loss:1.5682
#
# EPOCH[10] - STEP[160]
# Generator_loss:1.5927
# L1_loss:0.1937
# Discriminator_loss:0.7681
#
# EPOCH[10] - STEP[170]
# Generator_loss:0.1576
# L1_loss:0.2086
# Discriminator_loss:2.2214
#
# EPOCH[10] - STEP[180]
# Generator_loss:1.3682
# L1_loss:0.1787
# Discriminator_loss:0.5021
#
# EPOCH[10] - STEP[190]
# Generator_loss:2.6982
# L1_loss:0.1685
# Discriminator_loss:0.9107
#
# EPOCH[10] - STEP[200]
# Generator_loss:1.3647
# L1_loss:0.1645
# Discriminator_loss:0.4623
#
# EPOCH[10] - STEP[210]
# Generator_loss:0.9584
# L1_loss:0.2201
# Discriminator_loss:0.7056
#
# EPOCH[10] - STEP[220]
# Generator_loss:1.0138
# L1_loss:0.1549
# Discriminator_loss:0.6258
#
# EPOCH[10] - STEP[230]
# Generator_loss:2.5030
# L1_loss:0.2048
# Discriminator_loss:0.7287
#
# EPOCH[10] - STEP[240]
# Generator_loss:0.9771
# L1_loss:0.1724
# Discriminator_loss:1.0746
#
# EPOCH[10] - STEP[250]
# Generator_loss:2.0799
# L1_loss:0.1879
# Discriminator_loss:0.7727
#
# EPOCH[11] - STEP[10]
# Generator_loss:3.3745
# L1_loss:0.1754
# Discriminator_loss:2.0454
#
# EPOCH[11] - STEP[20]
# Generator_loss:0.4990
# L1_loss:0.1934
# Discriminator_loss:1.2401
#
# EPOCH[11] - STEP[30]
# Generator_loss:0.8675
# L1_loss:0.1821
# Discriminator_loss:0.9263
#
# EPOCH[11] - STEP[40]
# Generator_loss:0.8554
# L1_loss:0.1668
# Discriminator_loss:0.7034
#
# EPOCH[11] - STEP[50]
# Generator_loss:1.5935
# L1_loss:0.1869
# Discriminator_loss:0.8677
#
# EPOCH[11] - STEP[60]
# Generator_loss:1.0143
# L1_loss:0.1994
# Discriminator_loss:0.6587
#
# EPOCH[11] - STEP[70]
# Generator_loss:2.2143
# L1_loss:0.1658
# Discriminator_loss:0.5714
#
# EPOCH[11] - STEP[80]
# Generator_loss:0.8826
# L1_loss:0.1456
# Discriminator_loss:0.7165
#
# EPOCH[11] - STEP[90]
# Generator_loss:1.6118
# L1_loss:0.2100
# Discriminator_loss:0.7757
#
# EPOCH[11] - STEP[100]
# Generator_loss:2.3951
# L1_loss:0.1694
# Discriminator_loss:0.3461
#
# EPOCH[11] - STEP[110]
# Generator_loss:2.2558
# L1_loss:0.1997
# Discriminator_loss:0.2556
#
# EPOCH[11] - STEP[120]
# Generator_loss:1.2356
# L1_loss:0.1911
# Discriminator_loss:0.6938
#
# EPOCH[11] - STEP[130]
# Generator_loss:2.5202
# L1_loss:0.1694
# Discriminator_loss:0.7269
#
# EPOCH[11] - STEP[140]
# Generator_loss:1.6175
# L1_loss:0.1771
# Discriminator_loss:0.4008
#
# EPOCH[11] - STEP[150]
# Generator_loss:0.5734
# L1_loss:0.1486
# Discriminator_loss:1.2384
#
# EPOCH[11] - STEP[160]
# Generator_loss:1.6270
# L1_loss:0.1791
# Discriminator_loss:0.7508
#
# EPOCH[11] - STEP[170]
# Generator_loss:2.6663
# L1_loss:0.1510
# Discriminator_loss:0.8704
#
# EPOCH[11] - STEP[180]
# Generator_loss:1.7086
# L1_loss:0.1819
# Discriminator_loss:1.5543
#
# EPOCH[11] - STEP[190]
# Generator_loss:1.6796
# L1_loss:0.1517
# Discriminator_loss:1.0559
#
# EPOCH[11] - STEP[200]
# Generator_loss:2.0598
# L1_loss:0.1758
# Discriminator_loss:1.0007
#
# EPOCH[11] - STEP[210]
# Generator_loss:2.2568
# L1_loss:0.1645
# Discriminator_loss:0.8148
#
# EPOCH[11] - STEP[220]
# Generator_loss:1.0135
# L1_loss:0.1893
# Discriminator_loss:0.8127
#
# EPOCH[11] - STEP[230]
# Generator_loss:2.3116
# L1_loss:0.1325
# Discriminator_loss:1.1345
#
# EPOCH[11] - STEP[240]
# Generator_loss:2.0828
# L1_loss:0.1432
# Discriminator_loss:0.8903
#
# EPOCH[11] - STEP[250]
# Generator_loss:2.0122
# L1_loss:0.2154
# Discriminator_loss:0.4060
#
# EPOCH[12] - STEP[10]
# Generator_loss:0.9928
# L1_loss:0.1893
# Discriminator_loss:0.7006
#
# EPOCH[12] - STEP[20]
# Generator_loss:0.7688
# L1_loss:0.1612
# Discriminator_loss:1.0370
#
# EPOCH[12] - STEP[30]
# Generator_loss:0.9758
# L1_loss:0.1688
# Discriminator_loss:0.9128
#
# EPOCH[12] - STEP[40]
# Generator_loss:3.3702
# L1_loss:0.1401
# Discriminator_loss:1.4118
#
# EPOCH[12] - STEP[50]
# Generator_loss:1.1058
# L1_loss:0.1689
# Discriminator_loss:0.8293
#
# EPOCH[12] - STEP[60]
# Generator_loss:1.8078
# L1_loss:0.1822
# Discriminator_loss:0.4397
#
# EPOCH[12] - STEP[70]
# Generator_loss:1.2569
# L1_loss:0.2172
# Discriminator_loss:0.4741
#
# EPOCH[12] - STEP[80]
# Generator_loss:1.3630
# L1_loss:0.1696
# Discriminator_loss:0.5387
#
# EPOCH[12] - STEP[90]
# Generator_loss:1.4733
# L1_loss:0.1605
# Discriminator_loss:0.4405
#
# EPOCH[12] - STEP[100]
# Generator_loss:1.9397
# L1_loss:0.2213
# Discriminator_loss:0.4520
#
# EPOCH[12] - STEP[110]
# Generator_loss:3.6211
# L1_loss:0.1519
# Discriminator_loss:2.5572
#
# EPOCH[12] - STEP[120]
# Generator_loss:1.2630
# L1_loss:0.1773
# Discriminator_loss:0.5264
#
# EPOCH[12] - STEP[130]
# Generator_loss:1.8967
# L1_loss:0.1314
# Discriminator_loss:1.2423
#
# EPOCH[12] - STEP[140]
# Generator_loss:0.7277
# L1_loss:0.2398
# Discriminator_loss:0.9318
#
# EPOCH[12] - STEP[150]
# Generator_loss:2.9066
# L1_loss:0.1724
# Discriminator_loss:0.7026
#
# EPOCH[12] - STEP[160]
# Generator_loss:1.9015
# L1_loss:0.1596
# Discriminator_loss:0.5650
#
# EPOCH[12] - STEP[170]
# Generator_loss:1.4003
# L1_loss:0.1759
# Discriminator_loss:0.5924
#
# EPOCH[12] - STEP[180]
# Generator_loss:2.2394
# L1_loss:0.1974
# Discriminator_loss:0.3133
#
# EPOCH[12] - STEP[190]
# Generator_loss:1.9177
# L1_loss:0.1305
# Discriminator_loss:0.8053
#
# EPOCH[12] - STEP[200]
# Generator_loss:0.9332
# L1_loss:0.1349
# Discriminator_loss:0.8153
#
# EPOCH[12] - STEP[210]
# Generator_loss:1.9048
# L1_loss:0.1297
# Discriminator_loss:0.5010
#
# EPOCH[12] - STEP[220]
# Generator_loss:0.6535
# L1_loss:0.2176
# Discriminator_loss:1.1663
#
# EPOCH[12] - STEP[230]
# Generator_loss:2.4598
# L1_loss:0.1877
# Discriminator_loss:0.3662
#
# EPOCH[12] - STEP[240]
# Generator_loss:1.3152
# L1_loss:0.1810
# Discriminator_loss:0.7584
#
# EPOCH[12] - STEP[250]
# Generator_loss:2.0517
# L1_loss:0.1707
# Discriminator_loss:0.7737
#
# EPOCH[13] - STEP[10]
# Generator_loss:1.1974
# L1_loss:0.1443
# Discriminator_loss:0.8791
#
# EPOCH[13] - STEP[20]
# Generator_loss:1.1961
# L1_loss:0.1510
# Discriminator_loss:1.1409
#
# EPOCH[13] - STEP[30]
# Generator_loss:0.3673
# L1_loss:0.1888
# Discriminator_loss:1.4433
#
# EPOCH[13] - STEP[40]
# Generator_loss:1.8483
# L1_loss:0.1926
# Discriminator_loss:0.3400
#
# EPOCH[13] - STEP[50]
# Generator_loss:1.5948
# L1_loss:0.1692
# Discriminator_loss:0.7783
#
# EPOCH[13] - STEP[60]
# Generator_loss:1.8559
# L1_loss:0.1659
# Discriminator_loss:0.5225
#
# EPOCH[13] - STEP[70]
# Generator_loss:2.1718
# L1_loss:0.1466
# Discriminator_loss:2.1904
#
# EPOCH[13] - STEP[80]
# Generator_loss:1.9690
# L1_loss:0.1641
# Discriminator_loss:0.3674
#
# EPOCH[13] - STEP[90]
# Generator_loss:1.5658
# L1_loss:0.1462
# Discriminator_loss:0.7983
#
# EPOCH[13] - STEP[100]
# Generator_loss:3.3155
# L1_loss:0.1661
# Discriminator_loss:1.4101
#
# EPOCH[13] - STEP[110]
# Generator_loss:1.3227
# L1_loss:0.1684
# Discriminator_loss:0.6399
#
# EPOCH[13] - STEP[120]
# Generator_loss:0.5359
# L1_loss:0.1734
# Discriminator_loss:1.4883
#
# EPOCH[13] - STEP[130]
# Generator_loss:1.6651
# L1_loss:0.1522
# Discriminator_loss:0.4950
#
# EPOCH[13] - STEP[140]
# Generator_loss:3.0161
# L1_loss:0.1589
# Discriminator_loss:0.7782
#
# EPOCH[13] - STEP[150]
# Generator_loss:1.1089
# L1_loss:0.1602
# Discriminator_loss:0.5972
#
# EPOCH[13] - STEP[160]
# Generator_loss:1.9517
# L1_loss:0.1892
# Discriminator_loss:0.5478
#
# EPOCH[13] - STEP[170]
# Generator_loss:1.4684
# L1_loss:0.1302
# Discriminator_loss:0.8986
#
# EPOCH[13] - STEP[180]
# Generator_loss:1.5044
# L1_loss:0.1678
# Discriminator_loss:0.8290
#
# EPOCH[13] - STEP[190]
# Generator_loss:2.3136
# L1_loss:0.1383
# Discriminator_loss:0.4305
#
# EPOCH[13] - STEP[200]
# Generator_loss:2.4496
# L1_loss:0.1643
# Discriminator_loss:0.3697
#
# EPOCH[13] - STEP[210]
# Generator_loss:0.7444
# L1_loss:0.1653
# Discriminator_loss:1.3372
#
# EPOCH[13] - STEP[220]
# Generator_loss:0.8235
# L1_loss:0.1276
# Discriminator_loss:0.7930
#
# EPOCH[13] - STEP[230]
# Generator_loss:0.8177
# L1_loss:0.1787
# Discriminator_loss:0.7252
#
# EPOCH[13] - STEP[240]
# Generator_loss:2.5840
# L1_loss:0.1785
# Discriminator_loss:0.2923
#
# EPOCH[13] - STEP[250]
# ...
# L1_loss:0.1765
# Discriminator_loss:1.8601
#
# EPOCH[26] - STEP[190]
# Generator_loss:0.4208
# L1_loss:0.1436
# Discriminator_loss:1.3759
#
# EPOCH[26] - STEP[200]
# Generator_loss:2.5279
# L1_loss:0.1641
# Discriminator_loss:0.4650
#
# EPOCH[26] - STEP[210]
# Generator_loss:0.4373
# L1_loss:0.1622
# Discriminator_loss:1.2661
#
# EPOCH[26] - STEP[220]
# Generator_loss:1.7068
# L1_loss:0.1350
# Discriminator_loss:0.6831
#
# EPOCH[26] - STEP[230]
# Generator_loss:1.4033
# L1_loss:0.1535
# Discriminator_loss:0.5102
#
# EPOCH[26] - STEP[240]
# Generator_loss:0.7279
# L1_loss:0.1628
# Discriminator_loss:1.0459
#
# EPOCH[26] - STEP[250]
# Generator_loss:2.8064
# L1_loss:0.1617
# Discriminator_loss:0.6691
#
# EPOCH[27] - STEP[10]
# Generator_loss:0.3268
# L1_loss:0.1508
# Discriminator_loss:1.9157
#
# EPOCH[27] - STEP[20]
# Generator_loss:1.4450
# L1_loss:0.1393
# Discriminator_loss:0.5942
#
# EPOCH[27] - STEP[30]
# Generator_loss:0.6378
# L1_loss:0.1617
# Discriminator_loss:1.3458
#
# EPOCH[27] - STEP[40]
# Generator_loss:1.4244
# L1_loss:0.1770
# Discriminator_loss:0.5262
#
# EPOCH[27] - STEP[50]
# Generator_loss:1.4572
# L1_loss:0.1322
# Discriminator_loss:0.7560
#
# EPOCH[27] - STEP[60]
# Generator_loss:2.2328
# L1_loss:0.1487
# Discriminator_loss:0.4698
#
# EPOCH[27] - STEP[70]
# Generator_loss:0.8776
# L1_loss:0.1919
# Discriminator_loss:0.7164
#
# EPOCH[27] - STEP[80]
# Generator_loss:2.6165
# L1_loss:0.1302
# Discriminator_loss:0.5107
#
# EPOCH[27] - STEP[90]
# Generator_loss:1.4729
# L1_loss:0.1385
# Discriminator_loss:0.5187
#
# EPOCH[27] - STEP[100]
# Generator_loss:1.7924
# L1_loss:0.1615
# Discriminator_loss:0.6712
#
# EPOCH[27] - STEP[110]
# Generator_loss:2.0859
# L1_loss:0.1549
# Discriminator_loss:0.4406
#
# EPOCH[27] - STEP[120]
# Generator_loss:1.9381
# L1_loss:0.1871
# Discriminator_loss:0.4983
#
# EPOCH[27] - STEP[130]
# Generator_loss:3.6916
# L1_loss:0.1399
# Discriminator_loss:0.3019
#
# EPOCH[27] - STEP[140]
# Generator_loss:1.4643
# L1_loss:0.1282
# Discriminator_loss:1.1042
#
# EPOCH[27] - STEP[150]
# Generator_loss:2.5472
# L1_loss:0.1626
# Discriminator_loss:0.3464
#
# EPOCH[27] - STEP[160]
# Generator_loss:1.9578
# L1_loss:0.1416
# Discriminator_loss:0.4602
#
# EPOCH[27] - STEP[170]
# Generator_loss:3.3412
# L1_loss:0.2011
# Discriminator_loss:0.0768
#
# EPOCH[27] - STEP[180]
# Generator_loss:0.8412
# L1_loss:0.1281
# Discriminator_loss:0.9412
#
# EPOCH[27] - STEP[190]
# Generator_loss:1.1925
# L1_loss:0.1594
# Discriminator_loss:0.5740
#
# EPOCH[27] - STEP[200]
# Generator_loss:3.1556
# L1_loss:0.1596
# Discriminator_loss:1.7548
#
# EPOCH[27] - STEP[210]
# Generator_loss:1.1097
# L1_loss:0.1577
# Discriminator_loss:0.6886
#
# EPOCH[27] - STEP[220]
# Generator_loss:3.0805
# L1_loss:0.1755
# Discriminator_loss:0.3525
#
# EPOCH[27] - STEP[230]
# Generator_loss:1.5951
# L1_loss:0.1552
# Discriminator_loss:0.5177
#
# EPOCH[27] - STEP[240]
# Generator_loss:0.9426
# L1_loss:0.1682
# Discriminator_loss:0.8174
#
# EPOCH[27] - STEP[250]
# Generator_loss:3.0718
# L1_loss:0.1572
# Discriminator_loss:0.1704
#
# EPOCH[28] - STEP[10]
# Generator_loss:1.1463
# L1_loss:0.1405
# Discriminator_loss:0.6619
#
# EPOCH[28] - STEP[20]
# Generator_loss:3.2708
# L1_loss:0.1481
# Discriminator_loss:0.9662
#
# EPOCH[28] - STEP[30]
# Generator_loss:0.8038
# L1_loss:0.1177
# Discriminator_loss:0.9805
#
# EPOCH[28] - STEP[40]
# Generator_loss:1.4947
# L1_loss:0.1544
# Discriminator_loss:0.4804
#
# EPOCH[28] - STEP[50]
# Generator_loss:2.7191
# L1_loss:0.1603
# Discriminator_loss:0.2680
#
# EPOCH[28] - STEP[60]
# Generator_loss:3.8306
# L1_loss:0.1503
# Discriminator_loss:0.4082
#
# EPOCH[28] - STEP[70]
# Generator_loss:1.8100
# L1_loss:0.1442
# Discriminator_loss:0.4386
#
# EPOCH[28] - STEP[80]
# Generator_loss:3.0346
# L1_loss:0.1200
# Discriminator_loss:0.9158
#
# EPOCH[28] - STEP[90]
# Generator_loss:1.1921
# L1_loss:0.1474
# Discriminator_loss:0.7457
#
# EPOCH[28] - STEP[100]
# Generator_loss:1.4769
# L1_loss:0.1680
# Discriminator_loss:0.4788
#
# EPOCH[28] - STEP[110]
# Generator_loss:2.8032
# L1_loss:0.1645
# Discriminator_loss:0.2817
#
# EPOCH[28] - STEP[120]
# Generator_loss:1.7818
# L1_loss:0.1408
# Discriminator_loss:0.8850
#
# EPOCH[28] - STEP[130]
# Generator_loss:3.5806
# L1_loss:0.1506
# Discriminator_loss:1.8655
#
# EPOCH[28] - STEP[140]
# Generator_loss:3.0007
# L1_loss:0.1410
# Discriminator_loss:0.3330
#
# EPOCH[28] - STEP[150]
# Generator_loss:1.5007
# L1_loss:0.1540
# Discriminator_loss:0.3931
#
# EPOCH[28] - STEP[160]
# Generator_loss:2.2885
# L1_loss:0.1252
# Discriminator_loss:1.3323
#
# EPOCH[28] - STEP[170]
# Generator_loss:1.6390
# L1_loss:0.1521
# Discriminator_loss:0.3897
#
# EPOCH[28] - STEP[180]
# Generator_loss:2.7098
# L1_loss:0.1946
# Discriminator_loss:0.5075
#
# EPOCH[28] - STEP[190]
# Generator_loss:1.2279
# L1_loss:0.1523
# Discriminator_loss:0.7907
#
# EPOCH[28] - STEP[200]
# Generator_loss:1.0171
# L1_loss:0.1589
# Discriminator_loss:0.7050
#
# EPOCH[28] - STEP[210]
# Generator_loss:3.6446
# L1_loss:0.1620
# Discriminator_loss:1.0316
#
# EPOCH[28] - STEP[220]
# Generator_loss:0.7948
# L1_loss:0.1732
# Discriminator_loss:0.7949
#
# EPOCH[28] - STEP[230]
# Generator_loss:2.6330
# L1_loss:0.1404
# Discriminator_loss:0.4651
#
# EPOCH[28] - STEP[240]
# Generator_loss:3.2759
# L1_loss:0.1341
# Discriminator_loss:0.1784
#
# EPOCH[28] - STEP[250]
# Generator_loss:1.0010
# L1_loss:0.1410
# Discriminator_loss:0.6606
#
# EPOCH[29] - STEP[10]
# Generator_loss:2.1049
# L1_loss:0.1447
# Discriminator_loss:0.5310
#
# EPOCH[29] - STEP[20]
# Generator_loss:1.7700
# L1_loss:0.1407
# Discriminator_loss:0.3143
#
# EPOCH[29] - STEP[30]
# Generator_loss:3.3195
# L1_loss:0.1757
# Discriminator_loss:0.2201
#
# EPOCH[29] - STEP[40]
# Generator_loss:1.4329
# L1_loss:0.1318
# Discriminator_loss:0.8208
#
# EPOCH[29] - STEP[50]
# Generator_loss:1.5912
# L1_loss:0.1767
# Discriminator_loss:0.3862
#
# EPOCH[29] - STEP[60]
# Generator_loss:3.3628
# L1_loss:0.1508
# Discriminator_loss:1.5570
#
# EPOCH[29] - STEP[70]
# Generator_loss:3.2262
# L1_loss:0.1557
# Discriminator_loss:0.1858
#
# EPOCH[29] - STEP[80]
# Generator_loss:2.0758
# L1_loss:0.1548
# Discriminator_loss:0.6746
#
# EPOCH[29] - STEP[90]
# Generator_loss:1.8203
# L1_loss:0.1648
# Discriminator_loss:0.2808
#
# EPOCH[29] - STEP[100]
# Generator_loss:3.8358
# L1_loss:0.1554
# Discriminator_loss:0.2079
#
# EPOCH[29] - STEP[110]
# Generator_loss:3.0907
# L1_loss:0.1352
# Discriminator_loss:0.9614
#
# EPOCH[29] - STEP[120]
# Generator_loss:3.3828
# L1_loss:0.1389
# Discriminator_loss:2.2471
#
# EPOCH[29] - STEP[130]
# Generator_loss:2.4721
# L1_loss:0.2067
# Discriminator_loss:0.1464
#
# EPOCH[29] - STEP[140]
# Generator_loss:1.5005
# L1_loss:0.1395
# Discriminator_loss:0.4910
#
# EPOCH[29] - STEP[150]
# Generator_loss:1.7000
# L1_loss:0.1229
# Discriminator_loss:0.4615
#
# EPOCH[29] - STEP[160]
# Generator_loss:3.6226
# L1_loss:0.1507
# Discriminator_loss:1.4181
#
# EPOCH[29] - STEP[170]
# Generator_loss:1.5915
# L1_loss:0.1867
# Discriminator_loss:0.4331
#
# EPOCH[29] - STEP[180]
# Generator_loss:0.7339
# L1_loss:0.1420
# Discriminator_loss:0.8558
#
# EPOCH[29] - STEP[190]
# Generator_loss:4.9210
# L1_loss:0.1366
# Discriminator_loss:1.6306
#
# EPOCH[29] - STEP[200]
# Generator_loss:4.6542
# L1_loss:0.1174
# Discriminator_loss:3.0081
#
# EPOCH[29] - STEP[210]
# Generator_loss:0.8604
# L1_loss:0.1441
# Discriminator_loss:0.9683
#
# EPOCH[29] - STEP[220]
# Generator_loss:1.7922
# L1_loss:0.1841
# Discriminator_loss:0.5071
#
# EPOCH[29] - STEP[230]
# Generator_loss:0.9710
# L1_loss:0.1369
# Discriminator_loss:0.8111
#
# EPOCH[29] - STEP[240]
# Generator_loss:0.8915
# L1_loss:0.1988
# Discriminator_loss:0.7533
#
# EPOCH[29] - STEP[250]
# Generator_loss:2.5565
# L1_loss:0.1396
# Discriminator_loss:0.4873
#
# EPOCH[30] - STEP[10]
# Generator_loss:2.3886
# L1_loss:0.1386
# Discriminator_loss:0.9780
#
# EPOCH[30] - STEP[20]
# Generator_loss:1.8026
# L1_loss:0.1526
# Discriminator_loss:0.3524
#
# EPOCH[30] - STEP[30]
# Generator_loss:1.1734
# L1_loss:0.1410
# Discriminator_loss:0.6379
#
# EPOCH[30] - STEP[40]
# Generator_loss:1.4203
# L1_loss:0.1548
# Discriminator_loss:0.5656
#
# EPOCH[30] - STEP[50]
# Generator_loss:1.2208
# L1_loss:0.1762
# Discriminator_loss:0.6347
#
# EPOCH[30] - STEP[60]
# Generator_loss:1.4028
# L1_loss:0.1846
# Discriminator_loss:0.6745
#
# EPOCH[30] - STEP[70]
# Generator_loss:0.9291
# L1_loss:0.1489
# Discriminator_loss:0.7163
#
# EPOCH[30] - STEP[80]
# Generator_loss:3.5574
# L1_loss:0.1951
# Discriminator_loss:0.1063
#
# EPOCH[30] - STEP[90]
# Generator_loss:3.0658
# L1_loss:0.1703
# Discriminator_loss:0.3157
#
# EPOCH[30] - STEP[100]
# Generator_loss:3.0498
# L1_loss:0.1649
# Discriminator_loss:0.1486
#
# EPOCH[30] - STEP[110]
# Generator_loss:2.0624
# L1_loss:0.1638
# Discriminator_loss:0.3734
#
# EPOCH[30] - STEP[120]
# Generator_loss:1.6577
# L1_loss:0.1490
# Discriminator_loss:0.9408
#
# EPOCH[30] - STEP[130]
# Generator_loss:4.2961
# L1_loss:0.2283
# Discriminator_loss:0.0806
#
# EPOCH[30] - STEP[140]
# Generator_loss:2.5370
# L1_loss:0.1400
# Discriminator_loss:1.8601
#
# EPOCH[30] - STEP[150]
# Generator_loss:2.5799
# L1_loss:0.1285
# Discriminator_loss:0.6229
#
# EPOCH[30] - STEP[160]
# Generator_loss:1.2097
# L1_loss:0.1661
# Discriminator_loss:0.6106
#
# EPOCH[30] - STEP[170]
# Generator_loss:1.3649
# L1_loss:0.1491
# Discriminator_loss:0.7331
#
# EPOCH[30] - STEP[180]
# Generator_loss:4.2896
# L1_loss:0.1482
# Discriminator_loss:0.8351
#
# EPOCH[30] - STEP[190]
# Generator_loss:2.1100
# L1_loss:0.1423
# Discriminator_loss:0.4918
#
# EPOCH[30] - STEP[200]
# Generator_loss:3.5749
# L1_loss:0.1470
# Discriminator_loss:0.4959
#
# EPOCH[30] - STEP[210]
# Generator_loss:3.1864
# L1_loss:0.1582
# Discriminator_loss:0.1332
#
# EPOCH[30] - STEP[220]
# Generator_loss:1.8781
# L1_loss:0.1508
# Discriminator_loss:0.3069
#
# EPOCH[30] - STEP[230]
# Generator_loss:1.7178
# L1_loss:0.1320
# Discriminator_loss:0.7201
#
# EPOCH[30] - STEP[240]
# Generator_loss:0.9201
# L1_loss:0.1227
# Discriminator_loss:0.7656
#
# EPOCH[30] - STEP[250]
# Generator_loss:2.4318
# L1_loss:0.1739
# Discriminator_loss:0.2360

# %% [markdown]
# ## 5. 모델 테스트

# %%
for test_ind in range(0,5):
    
    f = val_path + os.listdir(val_path)[test_ind]
    print(f)
    sketch, colored = load_img(f)

    pred = generator(tf.expand_dims(sketch, 0))
    pred = denormalize(pred)

    plt.figure(figsize=(15, 5))
    plt.subplot(1,3,1); plt.imshow(denormalize(sketch))
    plt.subplot(1,3,2); plt.imshow(pred[0])
    plt.subplot(1,3,3); plt.imshow(denormalize(colored))
# Out:
# D:/project/aiffel_exp/data/exp17/cityscapes/val/1.jpg
# D:/project/aiffel_exp/data/exp17/cityscapes/val/2.jpg
# D:/project/aiffel_exp/data/exp17/cityscapes/val/3.jpg
# D:/project/aiffel_exp/data/exp17/cityscapes/val/4.jpg
# D:/project/aiffel_exp/data/exp17/cityscapes/val/5.jpg

# %% [markdown]
# ### 느낀점
#
# * 마지막 exp였음에도 굉장히 상세하게 설명해주는 노드였다. 단번에 이해하지 못했지만 관련 작업이나 궁금함이 생겼을 때 꼭 복기해야겠다.
# * 두번째로 다뤄보는 GAN이었다. cv 분야에서는 GAN이 가장 흥미롭게 다가온다.
# * 프로젝트에서는 나름의 시도와 변형을 요구했지만 결국 exp node의 코드를 복붙했다. 모델의 변형 및 구현은 아직도 멀게 느껴진다. 큰일이다..
# * EXP가 벌써 끝났다. 첫 EXP를 진행해야 할 때의 막막함은 사라졌지만, 학습과 이해에 대한 불안감은 더 커진 기분이다.
